# %%
import numpy as np
from numpy.polynomial import Polynomial as Poly
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Left Plane Fitting
A_x = [1.129288648260761e-05, -0.08009403713692657, 0.0003107144391614336, 0.012797873528955785, 0.0005295870938277623, -0.0009747008204006224, 0.00010114551418980388, 3.968574387602764e-07]
A_y = [0.07999814924773316, 1.7145219587770126e-05, -0.04006470379517542, 0.00013128098674423447, 0.0031745436156560103, 0.00011924483962515575, -0.0001666256258221374, 1.515537414584306e-05]
B_x = [1.411610810312764e-05, -0.1001175464211573, 0.0003883930489497228, 0.015997341911197397, 0.0006619838672826222, -0.001218376025499842, 0.00012643189273703638, 4.960717984706521e-07]
B_y = [0.09999768655966619, 2.14315244865344e-05, -0.050080879743974474, 0.00016410123343752557, 0.003968179519564681, 0.00014905604953358207, -0.000208282032278111, 1.8944217682340097e-05]
C_x = [-0.08730444109525554, -0.006038411912842335, 0.0019480640877697262, 0.02954182547087869, -0.02239356552307967, 0.005419375878885002, 0.00010688833690058729, -0.00014758582950897729]
C_y = [-0.02935430914372217, -0.04803664310194349, -0.05069851096683131, 0.04823695695975268, -0.024522775370319442, 0.0034302257248766694, 0.000970517201979338, -0.00022005316153193402]
D_x = [3.4747343022248285e-06, -0.02464431911905334, 9.560444281634296e-05, 0.003937807239681712, 0.000162949875022163, -0.00029990794473815584, 3.1121696673735556e-05, 1.221099811557898e-07]
D_y = [-0.011597133589474484, 0.01203679245902142, -0.05726952461757285, 0.04728991254517789, -0.03351780358840571, 0.010131978808776108, -0.0007682114483517649, -6.52844643872138e-05]
E_x = [-1.9284883733625186e-16, 1.4324042428771431e-15, -3.6555203154059035e-15, 4.3189076651658346e-15, -2.542849414643894e-15, 7.098433225234169e-16, -6.760715836529259e-17, -2.4439010417800376e-18]
E_y = [-0.05230614818378873, 0.017378857898768023, -0.06491611164974555, 0.06824930434892112, -0.04982551345687386, 0.014582082795063848, -0.0010355829250312493, -0.00010103550373527039]
F_x = [-0.07922115681627133, 0.0064245034694449385, 0.0021344474707275475, 0.02512408462146725, -0.020898976289620615, 0.005545020060861925, -2.7733258483555903e-05, -0.0001316598828257355]
F_y = [-0.04888948991749337, -0.04100243386330336, -0.050568505590458196, 0.05336130836442207, -0.02925741541443177, 0.004425371925477578, 0.001056446425428136, -0.0002546503426689543]
G_x = [-5.692831173187612e-16, 4.2389959233541044e-15, -1.1233596662274271e-14, 1.4258205079718426e-14, -9.514532901870432e-15, 3.366933068026824e-15, -5.829486054269246e-16, 3.704221547207857e-17]
G_y = [-0.08004422213631104, -0.04301265930703809, -0.10580878294257633, 0.08886009184138272, -0.03103902364866719, -0.001105418324450194, 0.0030330875126614357, -0.0004650360042865928]
H_x = [0.029867885022261887, -0.1015083446518684, 0.0003359302945983391, 0.006767707421146685, 0.007614704919851656, -0.002412001729076878, -6.519366276181607e-05, 5.434796710906423e-05]
H_y = [0.09842205910372219, 0.020210162361816802, -0.04976385386568556, -0.0023547588103848085, 0.0029934392163673065, 0.000915230066986905, -0.00032778979330257043, 1.8208984392037498e-05]
U_x = [0.009669615824629486, -0.03326996939355064, 0.0014227965133690036, 0.0029554816183596563, 0.0008772745633094239, 0.0007481061509797202, -0.00036920343536740816, 2.4962239045435592e-05]
U_y = [-0.0006682432219354362, 0.014768821071982609, -0.04974684856179978, 0.02978313440927041, -0.0197800620541211, 0.004525511094612111, 0.00037306235275841695, -0.00016158912158916643]
L_x = [-0.006204808983197836, 0.005367722922662346, 0.060298802271597424, -0.025501651107259254, -0.008539152550844633, 0.008702919013865187, -0.002133326874710949, 0.0001597568122447928]
L_y = [0.02047830349473066, -0.048896242660697795, -0.08047731295274864, 0.0441713134318154, -0.007739219889231084, -0.004285690146924385, 0.002074504051417415, -0.00021867040854111553]


A_poly = np.array([Poly(A_x), Poly(A_y)])
B_poly = np.array([Poly(B_x), Poly(B_y)])
C_poly = np.array([Poly(C_x), Poly(C_y)])
D_poly = np.array([Poly(D_x), Poly(D_y)])
E_poly = np.array([Poly(E_x), Poly(E_y)])
F_poly = np.array([Poly(F_x), Poly(F_y)])
G_poly = np.array([Poly(G_x), Poly(G_y)])
H_poly = np.array([Poly(H_x), Poly(H_y)])
U_poly = np.array([Poly(U_x), Poly(U_y)])
L_poly = np.array([Poly(L_x), Poly(L_y)])

# %%
def rot_matrix(angle):
    return np.array([[np.cos(angle), -np.sin(angle)], [np.sin(angle),  np.cos(angle)]])

def get_contact_point(theta, beta):
    rot_beta = rot_matrix(beta)
    
    H_l_poly = rot_beta @ [ H_poly[0], H_poly[1]]
    U_l_poly = rot_beta @ [ U_poly[0], U_poly[1]]
    F_l_poly = rot_beta @ [ F_poly[0], F_poly[1]]
    L_l_poly = rot_beta @ [ L_poly[0], L_poly[1]]
    L_r_poly = rot_beta @ [-L_poly[0], L_poly[1]]
    F_r_poly = rot_beta @ [-F_poly[0], F_poly[1]]
    U_r_poly = rot_beta @ [-U_poly[0], U_poly[1]]
    H_r_poly = rot_beta @ [-H_poly[0], H_poly[1]]
    
    H_l = np.array([H_l_poly[0](theta), H_l_poly[1](theta)])
    U_l = np.array([U_l_poly[0](theta), U_l_poly[1](theta)])
    F_l = np.array([F_l_poly[0](theta), F_l_poly[1](theta)])
    L_l = np.array([L_l_poly[0](theta), L_l_poly[1](theta)])
    L_r = np.array([L_r_poly[0](theta), L_r_poly[1](theta)])
    F_r = np.array([F_r_poly[0](theta), F_r_poly[1](theta)])
    U_r = np.array([U_r_poly[0](theta), U_r_poly[1](theta)])
    H_r = np.array([H_r_poly[0](theta), H_r_poly[1](theta)])
    
    G   = rot_beta @ np.array([G_poly[0](theta), G_poly[1](theta)])
    
    R = 0.1
    eps = 10e-4
    
    contact_height = []
    contact_height.append(U_l[1]-R if (H_l[0]-eps < U_l[0] < F_l[0]+eps) else 0)
    contact_height.append(L_l[1]-R if (F_l[0]-eps < L_l[0] < G[0]+eps) else 0)
    contact_height.append(G[1])
    contact_height.append(L_r[1]-R if (G[0]-eps < L_r[0] < F_r[0]+eps) else 0)
    contact_height.append(U_r[1]-R if (F_r[0]-eps < U_r[0] < H_r[0]+eps) else 0)
    
    # print(contact_height)
    
    if min(contact_height) >= 0: return None, None, None
    
    contact_rim = np.argmin(contact_height)
    
    if contact_rim == 0:
        alpha = -np.arccos(np.dot(np.array([0, -1]), F_l-U_l)/0.1) - np.deg2rad(50)
        P = rot_matrix(alpha+np.deg2rad(50)) @ (F_l_poly-U_l_poly)
        
    elif contact_rim == 1:
        alpha = -np.arccos(np.dot(np.array([0, -1]), G-L_l)/0.1)
        P = rot_matrix(alpha) @ (G_poly-L_l_poly)
        
    elif contact_rim == 2:
        alpha = 0
        P = G_poly.copy()
        
    elif contact_rim == 3:
        alpha = np.arccos(np.dot(np.array([0, -1]), G-L_r)/0.1)
        P = rot_matrix(alpha) @ (G_poly-L_r_poly)
        
    elif contact_rim == 4:
        alpha = np.arccos(np.dot(np.array([0, -1]), F_r-U_r)/0.1) + np.deg2rad(50)
        P = rot_matrix(alpha-np.deg2rad(50)) @ (F_r_poly-U_r_poly)
    
    return contact_rim, alpha, P

# %%
# Validate Contact Point Calculation
for theta in range(17, 120):
    beta = np.deg2rad(30)
    theta = np.deg2rad(theta)
    
    contact_rim, alpha, P = get_contact_point(theta, beta)
    
    if contact_rim is None: continue
    
    print('\n= = = = =')
    print(f'TB = ({np.rad2deg(theta)}, {np.rad2deg(beta)})')
    print(f'Alpha = {np.rad2deg(alpha)}')
    print(f'Contact Rim = {contact_rim}')
    print(f'P = {[round(P[0](theta), 6), round(P[1](theta), 6)]}')
    
    # Add Rotation Movement
    P = rot_matrix(beta) @ P
    print(f'P = {[round(P[0](theta), 6), round(P[1](theta), 6)]}')
# Out:
# = = = = =
# TB = (17.0, 29.999999999999996)
# Alpha = -29.997877800179825
# Contact Rim = 1
# P = [-0.05, -0.086611]
# P = [4e-06, -0.100007]
#
# = = = = =
# TB = (18.0, 29.999999999999996)
# Alpha = -29.65894643969218
# Contact Rim = 1
# P = [-0.050842, -0.086704]
# P = [-0.000678, -0.100509]
#
# = = = = =
# TB = (19.0, 29.999999999999996)
# Alpha = -29.307004619897302
# Contact Rim = 1
# P = [-0.051698, -0.086817]
# P = [-0.001363, -0.101035]
#
# = = = = =
# TB = (20.0, 29.999999999999996)
# Alpha = -28.942755956970945
# Contact Rim = 1
# P = [-0.052567, -0.086949]
# P = [-0.00205, -0.101584]
#
# = = = = =
# TB = (21.0, 29.999999999999996)
# Alpha = -28.566876718682252
# Contact Rim = 1
# P = [-0.053448, -0.087101]
# P = [-0.002737, -0.102156]
#
# = = = = =
# TB = (22.0, 29.999999999999996)
# Alpha = -28.18001729337131
# Contact Rim = 1
# P = [-0.054341, -0.087272]
# P = [-0.003424, -0.10275]
#
# = = = = =
# TB = (23.0, 29.999999999999996)
# Alpha = -27.78280353463952
# Contact Rim = 1
# P = [-0.055244, -0.087464]
# P = [-0.004111, -0.103368]
#
# = = = = =
# TB = (24.000000000000004, 29.999999999999996)
# Alpha = -27.375837995542096
# Contact Rim = 1
# P = [-0.056157, -0.087675]
# P = [-0.004796, -0.104007]
#
# = = = = =
# TB = (25.0, 29.999999999999996)
# Alpha = -26.95970106419114
# Contact Rim = 1
# P = [-0.05708, -0.087907]
# P = [-0.005479, -0.104669]
#
# = = = = =
# TB = (26.0, 29.999999999999996)
# Alpha = -26.5349520110852
# Contact Rim = 1
# P = [-0.05801, -0.088158]
# P = [-0.006159, -0.105352]
#
# = = = = =
# TB = (27.0, 29.999999999999996)
# Alpha = -26.10212995712356
# Contact Rim = 1
# P = [-0.058948, -0.08843]
# P = [-0.006836, -0.106057]
#
# = = = = =
# TB = (28.0, 29.999999999999996)
# Alpha = -25.661754770106246
# Contact Rim = 1
# P = [-0.059893, -0.088723]
# P = [-0.007508, -0.106783]
#
# = = = = =
# TB = (29.000000000000004, 29.999999999999996)
# Alpha = -25.21432789653191
# Contact Rim = 1
# P = [-0.060844, -0.089035]
# P = [-0.008175, -0.107529]
#
# = = = = =
# TB = (29.999999999999996, 29.999999999999996)
# Alpha = -24.760333134655777
# Contact Rim = 1
# P = [-0.0618, -0.089369]
# P = [-0.008836, -0.108296]
#
# = = = = =
# TB = (31.0, 29.999999999999996)
# Alpha = -24.300237354042366
# Contact Rim = 1
# P = [-0.062761, -0.089722]
# P = [-0.009491, -0.109082]
#
# = = = = =
# TB = (32.0, 29.999999999999996)
# Alpha = -23.834491166219355
# Contact Rim = 1
# P = [-0.063725, -0.090096]
# P = [-0.01014, -0.109888]
#
# = = = = =
# TB = (33.0, 29.999999999999996)
# Alpha = -23.363529550497038
# Contact Rim = 1
# P = [-0.064692, -0.09049]
# P = [-0.01078, -0.110713]
#
# = = = = =
# TB = (34.0, 29.999999999999996)
# Alpha = -22.887772438550495
# Contact Rim = 1
# P = [-0.065662, -0.090904]
# P = [-0.011413, -0.111556]
#
# = = = = =
# TB = (35.0, 29.999999999999996)
# Alpha = -22.407625260955605
# Contact Rim = 1
# P = [-0.066634, -0.091338]
# P = [-0.012037, -0.112418]
#
# = = = = =
# TB = (36.0, 29.999999999999996)
# Alpha = -21.92347945851731
# Contact Rim = 1
# P = [-0.067606, -0.091792]
# P = [-0.012652, -0.113298]
#
# = = = = =
# TB = (37.0, 29.999999999999996)
# Alpha = -21.435712960924196
# Contact Rim = 1
# P = [-0.068579, -0.092266]
# P = [-0.013258, -0.114195]
#
# = = = = =
# TB = (38.0, 29.999999999999996)
# Alpha = -20.944690634994863
# Contact Rim = 1
# P = [-0.069551, -0.09276]
# P = [-0.013853, -0.115108]
#
# = = = = =
# TB = (39.0, 29.999999999999996)
# Alpha = -20.450764704549723
# Contact Rim = 1
# P = [-0.070523, -0.093273]
# P = [-0.014438, -0.116038]
#
# = = = = =
# TB = (40.0, 29.999999999999996)
# Alpha = -19.954275143737572
# Contact Rim = 1
# P = [-0.071493, -0.093805]
# P = [-0.015012, -0.116984]
#
# = = = = =
# TB = (41.0, 29.999999999999996)
# Alpha = -19.455550045467525
# Contact Rim = 1
# P = [-0.072462, -0.094356]
# P = [-0.015575, -0.117946]
#
# = = = = =
# TB = (42.0, 29.999999999999996)
# Alpha = -18.95490596643925
# Contact Rim = 1
# P = [-0.073427, -0.094926]
# P = [-0.016127, -0.118922]
#
# = = = = =
# TB = (43.0, 29.999999999999996)
# Alpha = -18.45264825012475
# Contact Rim = 1
# P = [-0.07439, -0.095514]
# P = [-0.016667, -0.119913]
#
# = = = = =
# TB = (44.0, 29.999999999999996)
# Alpha = -17.949071328931176
# Contact Rim = 1
# P = [-0.07535, -0.09612]
# P = [-0.017194, -0.120918]
#
# = = = = =
# TB = (45.0, 29.999999999999996)
# Alpha = -17.444459006663287
# Contact Rim = 1
# P = [-0.076305, -0.096745]
# P = [-0.01771, -0.121936]
#
# = = = = =
# TB = (46.0, 29.999999999999996)
# Alpha = -16.939084722302866
# Contact Rim = 1
# P = [-0.077256, -0.097386]
# P = [-0.018213, -0.122967]
#
# = = = = =
# TB = (47.0, 29.999999999999996)
# Alpha = -16.433211796030232
# Contact Rim = 1
# P = [-0.078203, -0.098045]
# P = [-0.018703, -0.124011]
#
# = = = = =
# TB = (48.00000000000001, 29.999999999999996)
# Alpha = -15.927093658326934
# Contact Rim = 1
# P = [-0.079144, -0.09872]
# P = [-0.019181, -0.125067]
#
# = = = = =
# TB = (49.0, 29.999999999999996)
# Alpha = -15.420974062914548
# Contact Rim = 1
# P = [-0.08008, -0.099412]
# P = [-0.019645, -0.126134]
#
# = = = = =
# TB = (50.0, 29.999999999999996)
# Alpha = -14.915087284203162
# Contact Rim = 1
# P = [-0.081011, -0.10012]
# P = [-0.020097, -0.127212]
#
# = = = = =
# TB = (51.0, 29.999999999999996)
# Alpha = -14.409658299837274
# Contact Rim = 1
# P = [-0.081935, -0.100844]
# P = [-0.020536, -0.128301]
#
# = = = = =
# TB = (52.0, 29.999999999999996)
# Alpha = -13.904902958834022
# Contact Rim = 1
# P = [-0.082853, -0.101583]
# P = [-0.020961, -0.1294]
#
# = = = = =
# TB = (53.0, 29.999999999999996)
# Alpha = -13.401028135709263
# Contact Rim = 1
# P = [-0.083765, -0.102338]
# P = [-0.021374, -0.130509]
#
# = = = = =
# TB = (54.0, 29.999999999999996)
# Alpha = -12.898231870860124
# Contact Rim = 1
# P = [-0.08467, -0.103106]
# P = [-0.021773, -0.131628]
#
# = = = = =
# TB = (55.0, 29.999999999999996)
# Alpha = -12.396703497323829
# Contact Rim = 1
# P = [-0.085568, -0.103889]
# P = [-0.02216, -0.132755]
#
# = = = = =
# TB = (56.0, 29.999999999999996)
# Alpha = -11.896623753842475
# Contact Rim = 1
# P = [-0.086459, -0.104686]
# P = [-0.022533, -0.13389]
#
# = = = = =
# TB = (57.00000000000001, 29.999999999999996)
# Alpha = -11.398164883909589
# Contact Rim = 1
# P = [-0.087343, -0.105496]
# P = [-0.022894, -0.135034]
#
# = = = = =
# TB = (58.00000000000001, 29.999999999999996)
# Alpha = -10.901490720132012
# Contact Rim = 1
# P = [-0.08822, -0.106319]
# P = [-0.023241, -0.136185]
#
# = = = = =
# TB = (59.00000000000001, 29.999999999999996)
# Alpha = -10.40675675277439
# Contact Rim = 1
# P = [-0.089089, -0.107154]
# P = [-0.023577, -0.137343]
#
# = = = = =
# TB = (59.99999999999999, 29.999999999999996)
# Alpha = -9.914110180690548
# Contact Rim = 1
# P = [-0.089951, -0.108002]
# P = [-0.023899, -0.138508]
#
# = = = = =
# TB = (61.0, 29.999999999999996)
# Alpha = -9.423689941898346
# Contact Rim = 1
# P = [-0.090806, -0.108862]
# P = [-0.024209, -0.13968]
#
# = = = = =
# TB = (62.0, 29.999999999999996)
# Alpha = -8.935626719677465
# Contact Rim = 1
# P = [-0.091653, -0.109733]
# P = [-0.024507, -0.140858]
#
# = = = = =
# TB = (63.0, 29.999999999999996)
# Alpha = -8.450042918017877
# Contact Rim = 1
# P = [-0.092492, -0.110616]
# P = [-0.024793, -0.142042]
#
# = = = = =
# TB = (64.0, 29.999999999999996)
# Alpha = -7.967052597144797
# Contact Rim = 1
# P = [-0.093324, -0.111509]
# P = [-0.025067, -0.143232]
#
# = = = = =
# TB = (65.0, 29.999999999999996)
# Alpha = -7.486761355054418
# Contact Rim = 1
# P = [-0.094149, -0.112413]
# P = [-0.025329, -0.144427]
#
# = = = = =
# TB = (66.0, 29.999999999999996)
# Alpha = -7.009266133417637
# Contact Rim = 1
# P = [-0.094965, -0.113327]
# P = [-0.025579, -0.145626]
#
# = = = = =
# TB = (67.0, 29.999999999999996)
# Alpha = -6.534654913937094
# Contact Rim = 1
# P = [-0.095775, -0.11425]
# P = [-0.025818, -0.146831]
#
# = = = = =
# TB = (68.0, 29.999999999999996)
# Alpha = -6.063006250793404
# Contact Rim = 1
# P = [-0.096577, -0.115183]
# P = [-0.026046, -0.14804]
#
# = = = = =
# TB = (69.0, 29.999999999999996)
# Alpha = -5.594388549652464
# Contact Rim = 1
# P = [-0.097371, -0.116125]
# P = [-0.026263, -0.149253]
#
# = = = = =
# TB = (70.0, 29.999999999999996)
# Alpha = -5.128858941057381
# Contact Rim = 1
# P = [-0.098159, -0.117076]
# P = [-0.02647, -0.15047]
#
# = = = = =
# TB = (71.0, 29.999999999999996)
# Alpha = -4.666461479717541
# Contact Rim = 1
# P = [-0.098938, -0.118036]
# P = [-0.026665, -0.151692]
#
# = = = = =
# TB = (72.0, 29.999999999999996)
# Alpha = -4.207224174772622
# Contact Rim = 1
# P = [-0.099711, -0.119004]
# P = [-0.02685, -0.152916]
#
# = = = = =
# TB = (73.0, 29.999999999999996)
# Alpha = -3.7511538899521044
# Contact Rim = 1
# P = [-0.100476, -0.119981]
# P = [-0.027024, -0.154145]
#
# = = = = =
# TB = (74.0, 29.999999999999996)
# Alpha = -3.2982271266058887
# Contact Rim = 1
# P = [-0.101234, -0.120966]
# P = [-0.027188, -0.155376]
#
# = = = = =
# TB = (75.0, 29.999999999999996)
# Alpha = -2.848372253365923
# Contact Rim = 1
# P = [-0.101984, -0.121958]
# P = [-0.027342, -0.156611]
#
# = = = = =
# TB = (76.0, 29.999999999999996)
# Alpha = -2.401432272975676
# Contact Rim = 1
# P = [-0.102727, -0.122959]
# P = [-0.027485, -0.157849]
#
# = = = = =
# TB = (77.0, 29.999999999999996)
# Alpha = -1.9570776971548316
# Contact Rim = 1
# P = [-0.103461, -0.123969]
# P = [-0.027616, -0.15909]
#
# = = = = =
# TB = (78.0, 29.999999999999996)
# Alpha = -1.5145686392455175
# Contact Rim = 1
# P = [-0.104185, -0.124988]
# P = [-0.027733, -0.160335]
#
# = = = = =
# TB = (79.0, 29.999999999999996)
# Alpha = -1.0719331074715353
# Contact Rim = 1
# P = [-0.104894, -0.126021]
# P = [-0.027831, -0.161584]
#
# = = = = =
# TB = (80.0, 29.999999999999996)
# Alpha = -0.6216289584716452
# Contact Rim = 1
# P = [-0.105573, -0.127081]
# P = [-0.027888, -0.162841]
#
# = = = = =
# TB = (81.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.21251]
# P = [0.106255, -0.184039]
#
# = = = = =
# TB = (82.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.214353]
# P = [0.107176, -0.185635]
#
# = = = = =
# TB = (83.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.216199]
# P = [0.1081, -0.187234]
#
# = = = = =
# TB = (84.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.21805]
# P = [0.109025, -0.188837]
#
# = = = = =
# TB = (85.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.219903]
# P = [0.109952, -0.190442]
#
# = = = = =
# TB = (86.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.221761]
# P = [0.110881, -0.192051]
#
# = = = = =
# TB = (87.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.223622]
# P = [0.111811, -0.193663]
#
# = = = = =
# TB = (88.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.225487]
# P = [0.112744, -0.195278]
#
# = = = = =
# TB = (89.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.227356]
# P = [0.113678, -0.196896]
#
# = = = = =
# TB = (90.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.229228]
# P = [0.114614, -0.198518]
#
# = = = = =
# TB = (91.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.231104]
# P = [0.115552, -0.200142]
#
# = = = = =
# TB = (92.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.232983]
# P = [0.116492, -0.20177]
#
# = = = = =
# TB = (93.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.234866]
# P = [0.117433, -0.2034]
#
# = = = = =
# TB = (94.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.236752]
# P = [0.118376, -0.205033]
#
# = = = = =
# TB = (95.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.238641]
# P = [0.11932, -0.206669]
#
# = = = = =
# TB = (96.00000000000001, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.240533]
# P = [0.120266, -0.208307]
#
# = = = = =
# TB = (97.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.242427]
# P = [0.121213, -0.209948]
#
# = = = = =
# TB = (98.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.244324]
# P = [0.122162, -0.211591]
#
# = = = = =
# TB = (99.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.246223]
# P = [0.123111, -0.213235]
#
# = = = = =
# TB = (100.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.248124]
# P = [0.124062, -0.214881]
#
# = = = = =
# TB = (101.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.250026]
# P = [0.125013, -0.216529]
#
# = = = = =
# TB = (102.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [0.0, -0.25193]
# P = [0.125965, -0.218178]
#
# = = = = =
# TB = (103.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.253834]
# P = [0.126917, -0.219827]
#
# = = = = =
# TB = (104.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.25574]
# P = [0.12787, -0.221477]
#
# = = = = =
# TB = (105.00000000000001, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.257645]
# P = [0.128822, -0.223127]
#
# = = = = =
# TB = (106.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.25955]
# P = [0.129775, -0.224777]
#
# = = = = =
# TB = (107.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.261454]
# P = [0.130727, -0.226426]
#
# = = = = =
# TB = (108.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.263357]
# P = [0.131678, -0.228074]
#
# = = = = =
# TB = (109.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.265258]
# P = [0.132629, -0.22972]
#
# = = = = =
# TB = (110.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.267157]
# P = [0.133578, -0.231364]
#
# = = = = =
# TB = (111.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.269052]
# P = [0.134526, -0.233006]
#
# = = = = =
# TB = (112.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.270945]
# P = [0.135472, -0.234645]
#
# = = = = =
# TB = (113.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.272833]
# P = [0.136417, -0.23628]
#
# = = = = =
# TB = (114.00000000000001, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.274717]
# P = [0.137358, -0.237912]
#
# = = = = =
# TB = (115.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.276595]
# P = [0.138298, -0.239538]
#
# = = = = =
# TB = (116.00000000000001, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.278468]
# P = [0.139234, -0.24116]
#
# = = = = =
# TB = (117.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.280333]
# P = [0.140167, -0.242776]
#
# = = = = =
# TB = (118.00000000000001, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.282191]
# P = [0.141096, -0.244385]
#
# = = = = =
# TB = (119.0, 29.999999999999996)
# Alpha = 0.0
# Contact Rim = 2
# P = [-0.0, -0.284041]
# P = [0.142021, -0.245987]

# %%
def get_jacobian(theta, beta):
    contact_rim, alpha, P = get_contact_point(theta, beta)
    
    if contact_rim is None: return None
    
    P_deriv = np.array([P[0].deriv(), P[1].deriv()])
    
    # print('\n= = = = =')
    # print(f'TB = ({np.rad2deg(theta)}, {np.rad2deg(beta)})')
    # print(f'Alpha = {np.rad2deg(alpha)}')
    # print(f'Contact Rim = {contact_rim}')
    
    c_beta = np.cos(beta)
    s_beta = np.sin(beta)
    P[0] = P[0](theta)
    P[1] = P[1](theta)
    P_deriv[0] = P_deriv[0](theta)
    P_deriv[1] = P_deriv[1](theta)
    
    jacobian = np.array([[-(c_beta*P_deriv[0]-s_beta*P_deriv[1])/2 + (-s_beta*P[0]-c_beta*P[1])/2,
                           (c_beta*P_deriv[0]-s_beta*P_deriv[1])/2 + (-s_beta*P[0]-c_beta*P[1])/2],
                         [-(s_beta*P_deriv[0]+c_beta*P_deriv[1])/2 +  (c_beta*P[0]-s_beta*P[1])/2,
                           (s_beta*P_deriv[0]+c_beta*P_deriv[1])/2 +  (c_beta*P[0]-s_beta*P[1])/2]])
    
    return jacobian

# %%
# Validate Jacobian Calculation
theta_values = np.linspace(np.deg2rad(17), np.deg2rad(160), 1000)
beta_values = np.linspace(np.deg2rad(-180), np.deg2rad(180), 1000)

# Initialize the determinant matrix
determinants = np.zeros((len(theta_values), len(beta_values)))

# Calculate determinants
for i, theta in enumerate(theta_values):
    for j, beta in enumerate(beta_values):
        jacobian = get_jacobian(theta, beta)
        if jacobian is None:
            determinants[i, j] = np.inf
        else:
            det = np.linalg.det(jacobian)
            determinants[i, j] = det

# Plotting
plt.figure(figsize=(10, 5))
plt.imshow(determinants, extent=[-180, 180, 160, 17], aspect='auto', cmap='coolwarm')
plt.colorbar(label='Determinant of Jacobian')
plt.xlabel('Beta (degrees)')
plt.ylabel('Theta (degrees)')
plt.title('Determinant of the Jacobian Matrix')
plt.gca().invert_yaxis()
plt.show()
# Out:
# /tmp/ipykernel_91809/4090983369.py:60: RuntimeWarning: invalid value encountered in arccos
#   alpha = np.arccos(np.dot(np.array([0, -1]), F_r-U_r)/0.1) + np.deg2rad(50)
# /home/yisyuan/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /tmp/ipykernel_91809/4090983369.py:44: RuntimeWarning: invalid value encountered in arccos
#   alpha = -np.arccos(np.dot(np.array([0, -1]), F_l-U_l)/0.1) - np.deg2rad(50)
